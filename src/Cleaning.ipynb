# %% [markdown]
# ### Importando as bibliotecas

# %%
from pandas import read_excel, DataFrame, get_dummies
from numpy import nan, int64, int16
from constants import ordinal_mappings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pandas import read_excel, DataFrame, get_dummies
#       2 from numpy import nan, int64, int16
# ----> 3 from constants import ordinal_mappings
#
# File c:\Users\joaog\OneDrive\Área de Trabalho\CEFET7\repo_Análise_de_TCC\Sintomas-Musculoesquel-ticos-em-Universit-rios\src\constants.py:113
#     110 for col, mapping in ordinal_mappings.items():
#     111     # Ignora categorias com valor None
#     112     reverse_mapping = {v: k for k, v in mapping.items() if v is not None}
# --> 113     ordinal_inverse_mappings[col] = reverse_mapping
#
# NameError: name 'ordinal_inverse_mappings' is not defined

# %% [markdown]
# ### Leitura dos Dados

# %%
df = read_excel("../Data/Sintomas Musculoesqueléticos em Universitários.xlsx")
df['IDADE'] = df['IDADE'].astype(str)

# %% [markdown]
# ### Primeiras impressões dos dados

# %%
df.head(5)
# Out:
#      Carimbo de data/hora           CONCORDOU COM OS TERMOS  \
# 0 2024-11-12 16:01:10.064                               NaN
# 1 2024-11-12 19:44:40.157                               NaN
# 2 2024-11-19 16:36:21.891                     Não concordo.
# 3 2024-11-25 22:45:05.801  Eu concordo com os termos acima.
# 4 2024-12-03 09:10:49.569  Eu concordo com os termos acima.
#
#                        NOME COMPLETO IDADE        CURSO       SEXO  \
# 0        Nicole Aska Silveira Yamada    20    Medicina    FEMININO
# 1      Carlos Rodrigues Dias Júnior     21    Medicina   MASCULINO
# 2                                NaN   nan          NaN        NaN
# 3  Maria Fernanda Santos Nascimento     26  Psicologia    FEMININO
# 4       LUCILIA CAMPOS FAGUNDES MOTA    43  PSICOLOGIA    FEMININO
#
#                 ESTADO CIVIL RAÇA/COR DA PELE                 RENDA FAMILIAR  \
# 0               SOLTEIRO (A)           BRANCA  MAIOR QUE 10 SALÁRIOS-MÍNIMOS
# 1               SOLTEIRO (A)            PARDA           1-5 SALÁRIOS-MÍNIMOS
# 2                        NaN              NaN                            NaN
# 3               SOLTEIRO (A)            PARDA           1-5 SALÁRIOS-MÍNIMOS
# 4  CASADO (A) /UNIÃO ESTÁVEL           BRANCA  MAIOR QUE 10 SALÁRIOS-MÍNIMOS
#
#   Quanto você se preocupou com a sua dor ou com o desconforto físico?    ...  \
# 0                                        Muito pouco                     ...
# 1                                           Bastante                     ...
# 2                                                NaN                     ...
# 3                                      Mais ou menos                     ...
# 4                                      Mais ou menos                     ...
#
#   Em que medida você tem dificuldade para exercer suas atividades diárias?    \
# 0                                        Muito pouco
# 1                                        Muito pouco
# 2                                                NaN
# 3                                      Mais ou menos
# 4                                      Mais ou menos
#
#   Qual a sua frequência de atividades físicas semanais?    \
# 0                                         5 a 6 dias
# 1                                         3 a 4 dias
# 2                                                NaN
# 3                                               Nada
# 4                                               Nada
#
#   Com que frequência você utiliza dispositivos eletrônicos?     \
# 0                                       Extremamente
# 1                                           Bastante
# 2                                                NaN
# 3                                       Extremamente
# 4                                           Bastante
#
#   Você fica sentado estudando em média quantas horas por dia?   \
# 0                                            4 horas
# 1                                    6 horas ou mais
# 2                                                NaN
# 3                                            3 horas
# 4                                            4 horas
#
#   As suas atividades acadêmicas/estágios influenciam nas dores que sente?   \
# 0                                        Muito pouco
# 1                                           Bastante
# 2                                                NaN
# 3                                        Muito pouco
# 4                                           Bastante
#
#   Você se sente muito estressado/ansioso?   \
# 0                            Mais ou menos
# 1                            Mais ou menos
# 2                                      NaN
# 3                                 Bastante
# 4                                 Bastante
#
#   Nos últimos 6 MESES, você teve problemas (como formigamento, dor ou dormência) em alguma parte do corpo:   \
# 0                                                Pé
# 1                                                Não
# 2                                                NaN
# 3                                                Sim
# 4                                                Sim
#
#   Nos últimos 6 MESES, você foi impedido de realizar suas atividades normais (trabalho, atividades domésticas e de lazer) por causa desses problemas?  \
# 0                                                Não
# 1                                                Não
# 2                                                NaN
# 3                                                Sim
# 4                                                Não
#
#   Nos últimos 6 MESES, você consultou algum profissional da área da saúde (médico, fisioterapeuta) por causa dessa condição?  \
# 0                                                Não
# 1                                                Não
# 2                                                NaN
# 3                                                Não
# 4                                                Não
#
#   Nos últimos 7 DIAS, você teve/tem algum problema/sintoma musculoesquelético?
# 0                                                Não
# 1                                                Não
# 2                                                NaN
# 3                                                Sim
# 4                                                Sim
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Removendo todas as linhas onde os valores de todas as colunas são NaN

# %%
len(df)



df = df[df[[str(x) for x in df.columns]].notnull().all(1)]  #Filtro que seleciona dados não nulos


df.drop(
    columns=['NOME COMPLETO',
    'Carimbo de data/hora',
    'CONCORDOU COM OS TERMOS'], inplace = True
)

# %% [markdown]
# ### Conhecendo melhor valores possíveis em cada coluna para elaboração da análise de dados

# %%
map_col_values = lambda df: {col: df[col].unique().tolist() for col in df.columns}

# %%
df.columns
# Out:
# Index(['IDADE', 'CURSO', 'SEXO', 'ESTADO CIVIL', 'RAÇA/COR DA PELE',
#        'RENDA FAMILIAR',
#        'Quanto você se preocupou com a sua dor ou com o desconforto físico?  ',
#        'Quanto você se preocupou com a sua saúde?  ',
#        'Em que medida você acha que a sua dor (física) te impede de fazer o que precisa?  ',
#        'Você tem alguma dificuldade para dormir ou dificuldade com o sono?   ',
#        'Em que medida você tem dificuldade para exercer suas atividades diárias?  ',
#        'Qual a sua frequência de atividades físicas semanais?  ',
#        'Com que frequência você utiliza dispositivos eletrônicos?   ',
#        'Você fica sentado estudando em média quantas horas por dia? ',
#        'As suas atividades acadêmicas/estágios influenciam nas dores que sente? ',
#        'Você se sente muito estressado/ansioso? ',
#        'Nos últimos 6 MESES, você teve problemas (como formigamento, dor ou dormência) em alguma parte do corpo: ',
#        'Nos últimos 6 MESES, você foi impedido de realizar suas atividades normais (trabalho, atividades domésticas e de lazer) por causa desses problemas?',
#        'Nos últimos 6 MESES, você consultou algum profissional da área da saúde (médico, fisioterapeuta) por causa dessa condição?',
#        'Nos últimos 7 DIAS, você teve/tem algum problema/sintoma musculoesquelético?'],
#       dtype='object')

# %%
valores_unicos = map_col_values(df)

# %%
for k,v in valores_unicos.items():
    print(f'{k} ==> {v} \n\n')
# Out:
# IDADE ==> ['26', '43', '25', '22', '18', '24', '22 anos ', '37', '21 anos', '50 anos', '45', '18 anos', '19', '20', '19 anos ', '21', '23 anos', '23', '51 anos ', '20 anos ', '29', '36', '20 anos', '32', '19 anos', '47', '51', '46', '3-', '21 anos ', '27', '54 anos', '31', '35', '41', '28', '34', '24 anos', '18 anos ', '17', 'Rodrigues Silva ', '30', '50']
#
#
# CURSO ==> ['Psicologia ', 'PSICOLOGIA ', 'psicologia ', 'Psicologia - Formação de Psicologo', 'Psicologia', 'psicologia', 'piscologia', 'Medicina', 'Medicina ', 'medicina', 'medicina ', 'Odontologia ', 'Administração ', 'Fisioterapia ', 'Engenharia da computação ', 'Engenharia de computação', 'Farmácia ', 'Direito', 'direito ', 'direito', 'Farma ', 'Farmácia', 'Farmacia ', 'Arquitetura ', 'Enfermagem ', 'Ciências econômicas ', 'Direito ']
#
#
# SEXO ==> ['FEMININO', 'MASCULINO']
#
#
# ESTADO CIVIL ==> ['SOLTEIRO (A)', 'CASADO (A) /UNIÃO ESTÁVEL', 'DIVORCIADO (A)', 'Namorando']
#
#
# RAÇA/COR DA PELE ==> ['PARDA', 'BRANCA', 'PRETA', 'AMARELA', 'INDÍGENA']
#
#
# RENDA FAMILIAR ==> ['1-5 SALÁRIOS-MÍNIMOS', 'MAIOR QUE 10 SALÁRIOS-MÍNIMOS', '5-10 SALÁRIOS-MÍNIMOS', 'MENOR QUE 1 SALÁRIO-MÍNIMO']
#
#
# Quanto você se preocupou com a sua dor ou com o desconforto físico?   ==> ['Mais ou menos', 'Muito pouco', 'Bastante', 'Nada', 'Extremamente']
#
#
# Quanto você se preocupou com a sua saúde?   ==> ['Mais ou menos', 'Bastante', 'Extremamente', 'Muito pouco', 'Nada']
#
#
# Em que medida você acha que a sua dor (física) te impede de fazer o que precisa?   ==> ['Bastante', 'Muito pouco', 'Mais ou menos', 'Nada', 'Extremamente']
#
#
# Você tem alguma dificuldade para dormir ou dificuldade com o sono?    ==> ['Mais ou menos', 'Extremamente', 'Muito pouco', 'Bastante', 'Nada']
#
#
# Em que medida você tem dificuldade para exercer suas atividades diárias?   ==> ['Mais ou menos', 'Nada', 'Bastante', 'Muito pouco', 'Extremamente']
#
#
# Qual a sua frequência de atividades físicas semanais?   ==> ['Nada', '5 a 6 dias', '1 a 2 dias', 'Todos os dias', '3 a 4 dias']
#
#
# Com que frequência você utiliza dispositivos eletrônicos?    ==> ['Extremamente', 'Bastante', 'Nada', 'Mais ou menos', 'Muito pouco']
#
#
# Você fica sentado estudando em média quantas horas por dia?  ==> ['3 horas', '4 horas', '1 a 2 horas', '6 horas ou mais', '5 horas']
#
#
# As suas atividades acadêmicas/estágios influenciam nas dores que sente?  ==> ['Muito pouco', 'Bastante', 'Mais ou menos', 'Nada', 'Extremamente']
#
#
# Você se sente muito estressado/ansioso?  ==> ['Bastante', 'Extremamente', 'Muito pouco', 'Mais ou menos', 'Nada']
#
#
# Nos últimos 6 MESES, você teve problemas (como formigamento, dor ou dormência) em alguma parte do corpo:  ==> ['Sim', 'Não']
#
#
# Nos últimos 6 MESES, você foi impedido de realizar suas atividades normais (trabalho, atividades domésticas e de lazer) por causa desses problemas? ==> ['Sim', 'Não']
#
#
# Nos últimos 6 MESES, você consultou algum profissional da área da saúde (médico, fisioterapeuta) por causa dessa condição? ==> ['Não', 'Sim']
#
#
# Nos últimos 7 DIAS, você teve/tem algum problema/sintoma musculoesquelético? ==> ['Sim', 'Não']

# %% [markdown]
# ### Removendo cópias de valores categóricos escritas de formas diferentes

# %%
# Funções de normalização:

farmacia_norm = lambda curso : 'Farmácia' if curso in set(['Farma ', 'Farmácia', 'Farmacia ', 'Farmácia ']) else curso

direito_norm = lambda curso : 'Direito' if curso in set([ 'Direito ', 'direito ', 'Direito', 'Direito ' 'direito ', 'direito']) else farmacia_norm(curso)

eng_norm = lambda curso : 'Engenharia da Computação' if curso in set(['Engenharia da computação ', 'Engenharia de computação']) else direito_norm(curso)

medicina_norm = lambda curso : 'Medicina' if curso in set(['Medicina', 'Medicina ', 'medicina', 'medicina ']) else eng_norm(curso)

psicologia_norm = lambda curso : 'Psicologia' if curso in set(['Psicologia ', 'PSICOLOGIA ', 'psicologia ', 'Psicologia - Formação de Psicologo', 'Psicologia', 'psicologia', 'piscologia']) else medicina_norm(curso)

df['CURSO'] = df['CURSO'].map(psicologia_norm) #Filtrando dados repetidos

# %%
#Verificando filtragem
df['CURSO'].unique().tolist()
df['IDADE'].unique().tolist()
# Out:
# ['26',
#  '43',
#  '25',
#  '22',
#  '18',
#  '24',
#  '22 anos ',
#  '37',
#  '21 anos',
#  '50 anos',
#  '45',
#  '18 anos',
#  '19',
#  '20',
#  '19 anos ',
#  '21',
#  '23 anos',
#  '23',
#  '51 anos ',
#  '20 anos ',
#  '29',
#  '36',
#  '20 anos',
#  '32',
#  '19 anos',
#  '47',
#  '51',
#  '46',
#  '3-',
#  '21 anos ',
#  '27',
#  '54 anos',
#  '31',
#  '35',
#  '41',
#  '28',
#  '34',
#  '24 anos',
#  '18 anos ',
#  '17',
#  'Rodrigues Silva ',
#  '30',
#  '50']

# %% [markdown]
# ### Transformando idades em números inteiros

# %%
somente_numeros_da_idade = lambda idade : idade.join(s.strip() for s in idade.split())[:2]

df['IDADE'] = df['IDADE'].map(somente_numeros_da_idade)

# ======================================
# FUNÇÃO PARA TRATAR COLUNAS ESPECIAIS
# ======================================

def clean_age(age_str):
    try:
        # Extrai números de strings como "21 anos" → 21
        return int(''.join(filter(str.isdigit, str(age_str))))
    except:
        return nan  # Trata casos como "Rodrigues Silva"

df['IDADE'] = df['IDADE'].apply(clean_age)

df.head(2)
# Out:
#    IDADE       CURSO      SEXO               ESTADO CIVIL RAÇA/COR DA PELE  \
# 3   26.0  Psicologia  FEMININO               SOLTEIRO (A)            PARDA
# 4   43.0  Psicologia  FEMININO  CASADO (A) /UNIÃO ESTÁVEL           BRANCA
#
#                   RENDA FAMILIAR  \
# 3           1-5 SALÁRIOS-MÍNIMOS
# 4  MAIOR QUE 10 SALÁRIOS-MÍNIMOS
#
#   Quanto você se preocupou com a sua dor ou com o desconforto físico?    \
# 3                                      Mais ou menos
# 4                                      Mais ou menos
#
#   Quanto você se preocupou com a sua saúde?    \
# 3                               Mais ou menos
# 4                               Mais ou menos
#
#   Em que medida você acha que a sua dor (física) te impede de fazer o que precisa?    \
# 3                                           Bastante
# 4                                        Muito pouco
#
#   Você tem alguma dificuldade para dormir ou dificuldade com o sono?     \
# 3                                      Mais ou menos
# 4                                       Extremamente
#
#   Em que medida você tem dificuldade para exercer suas atividades diárias?    \
# 3                                      Mais ou menos
# 4                                      Mais ou menos
#
#   Qual a sua frequência de atividades físicas semanais?    \
# 3                                               Nada
# 4                                               Nada
#
#   Com que frequência você utiliza dispositivos eletrônicos?     \
# 3                                       Extremamente
# 4                                           Bastante
#
#   Você fica sentado estudando em média quantas horas por dia?   \
# 3                                            3 horas
# 4                                            4 horas
#
#   As suas atividades acadêmicas/estágios influenciam nas dores que sente?   \
# 3                                        Muito pouco
# 4                                           Bastante
#
#   Você se sente muito estressado/ansioso?   \
# 3                                 Bastante
# 4                                 Bastante
#
#   Nos últimos 6 MESES, você teve problemas (como formigamento, dor ou dormência) em alguma parte do corpo:   \
# 3                                                Sim
# 4                                                Sim
#
#   Nos últimos 6 MESES, você foi impedido de realizar suas atividades normais (trabalho, atividades domésticas e de lazer) por causa desses problemas?  \
# 3                                                Sim
# 4                                                Não
#
#   Nos últimos 6 MESES, você consultou algum profissional da área da saúde (médico, fisioterapeuta) por causa dessa condição?  \
# 3                                                Não
# 4                                                Não
#
#   Nos últimos 7 DIAS, você teve/tem algum problema/sintoma musculoesquelético?
# 3                                                Sim
# 4                                                Sim

# %% [markdown]
# ### Tratamento de valores ordinais

# %%
print(ordinal_mappings)
# Mapeamentos ordinais:
for col, mapping in ordinal_mappings.items():
    if col in df.columns:
        df[col] = df[col].str.strip().map(mapping)

# 3. Colunas não tratadas (preservadas com valores originais)
print("Colunas não convertidas (avaliar necessidade manual):")
non_encoded = [col for col in df.columns if col not in ordinal_mappings]
print(non_encoded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(ordinal_mappings)
#       2 # Mapeamentos ordinais:
#       3 for col, mapping in ordinal_mappings.items():
#
# NameError: name 'ordinal_mappings' is not defined

# %%
df.head(2)
# Out:
#    IDADE       CURSO      SEXO               ESTADO CIVIL RAÇA/COR DA PELE  \
# 3   26.0  Psicologia  FEMININO               SOLTEIRO (A)            PARDA
# 4   43.0  Psicologia  FEMININO  CASADO (A) /UNIÃO ESTÁVEL           BRANCA
#
#                   RENDA FAMILIAR  \
# 3           1-5 SALÁRIOS-MÍNIMOS
# 4  MAIOR QUE 10 SALÁRIOS-MÍNIMOS
#
#    Quanto você se preocupou com a sua dor ou com o desconforto físico?    \
# 3                                                  3
# 4                                                  3
#
#    Quanto você se preocupou com a sua saúde?    \
# 3                                            3
# 4                                            3
#
#    Em que medida você acha que a sua dor (física) te impede de fazer o que precisa?    \
# 3                                                  4
# 4                                                  2
#
#    Você tem alguma dificuldade para dormir ou dificuldade com o sono?     \
# 3                                                  3
# 4                                                  5
#
#    Em que medida você tem dificuldade para exercer suas atividades diárias?    \
# 3                                                  3
# 4                                                  3
#
#    Qual a sua frequência de atividades físicas semanais?    \
# 3                                                  1
# 4                                                  1
#
#    Com que frequência você utiliza dispositivos eletrônicos?     \
# 3                                                  5
# 4                                                  4
#
#    Você fica sentado estudando em média quantas horas por dia?   \
# 3                                                  2
# 4                                                  3
#
#    As suas atividades acadêmicas/estágios influenciam nas dores que sente?   \
# 3                                                  2
# 4                                                  4
#
#    Você se sente muito estressado/ansioso?   \
# 3                                         4
# 4                                         4
#
#    Nos últimos 6 MESES, você teve problemas (como formigamento, dor ou dormência) em alguma parte do corpo:   \
# 3                                                2.0
# 4                                                2.0
#
#    Nos últimos 6 MESES, você foi impedido de realizar suas atividades normais (trabalho, atividades domésticas e de lazer) por causa desses problemas?  \
# 3                                                  2
# 4                                                  1
#
#    Nos últimos 6 MESES, você consultou algum profissional da área da saúde (médico, fisioterapeuta) por causa dessa condição?  \
# 3                                                  1
# 4                                                  1
#
#    Nos últimos 7 DIAS, você teve/tem algum problema/sintoma musculoesquelético?
# 3                                                2.0
# 4                                                2.0

# %% [markdown]
# ### Dataset Pronto para Análise

# %%
df.head(3)
# Out:
#    IDADE       CURSO      SEXO               ESTADO CIVIL RAÇA/COR DA PELE  \
# 3   26.0  Psicologia  FEMININO               SOLTEIRO (A)            PARDA
# 4   43.0  Psicologia  FEMININO  CASADO (A) /UNIÃO ESTÁVEL           BRANCA
# 5   25.0  Psicologia  FEMININO               SOLTEIRO (A)            PARDA
#
#                   RENDA FAMILIAR  \
# 3           1-5 SALÁRIOS-MÍNIMOS
# 4  MAIOR QUE 10 SALÁRIOS-MÍNIMOS
# 5           1-5 SALÁRIOS-MÍNIMOS
#
#    Quanto você se preocupou com a sua dor ou com o desconforto físico?    \
# 3                                                  3
# 4                                                  3
# 5                                                  2
#
#    Quanto você se preocupou com a sua saúde?    \
# 3                                            3
# 4                                            3
# 5                                            4
#
#    Em que medida você acha que a sua dor (física) te impede de fazer o que precisa?    \
# 3                                                  4
# 4                                                  2
# 5                                                  3
#
#    Você tem alguma dificuldade para dormir ou dificuldade com o sono?     \
# 3                                                  3
# 4                                                  5
# 5                                                  5
#
#    Em que medida você tem dificuldade para exercer suas atividades diárias?    \
# 3                                                  3
# 4                                                  3
# 5                                                  3
#
#    Qual a sua frequência de atividades físicas semanais?    \
# 3                                                  1
# 4                                                  1
# 5                                                  1
#
#    Com que frequência você utiliza dispositivos eletrônicos?     \
# 3                                                  5
# 4                                                  4
# 5                                                  5
#
#    Você fica sentado estudando em média quantas horas por dia?   \
# 3                                                  2
# 4                                                  3
# 5                                                  3
#
#    As suas atividades acadêmicas/estágios influenciam nas dores que sente?   \
# 3                                                  2
# 4                                                  4
# 5                                                  3
#
#    Você se sente muito estressado/ansioso?   \
# 3                                         4
# 4                                         4
# 5                                         5
#
#    Nos últimos 6 MESES, você teve problemas (como formigamento, dor ou dormência) em alguma parte do corpo:   \
# 3                                                2.0
# 4                                                2.0
# 5                                                2.0
#
#    Nos últimos 6 MESES, você foi impedido de realizar suas atividades normais (trabalho, atividades domésticas e de lazer) por causa desses problemas?  \
# 3                                                  2
# 4                                                  1
# 5                                                  1
#
#    Nos últimos 6 MESES, você consultou algum profissional da área da saúde (médico, fisioterapeuta) por causa dessa condição?  \
# 3                                                  1
# 4                                                  1
# 5                                                  1
#
#    Nos últimos 7 DIAS, você teve/tem algum problema/sintoma musculoesquelético?
# 3                                                2.0
# 4                                                2.0
# 5                                                2.0

# %%
print(len(df['As suas atividades acadêmicas/estágios influenciam nas dores que sente? ']))
df.dropna(inplace= True)
print(len(df['As suas atividades acadêmicas/estágios influenciam nas dores que sente? ']))
# Out:
# 197
# 196

# %%
df['Nos últimos 6 MESES, você teve problemas (como formigamento, dor ou dormência) em alguma parte do corpo: '] = df['Nos últimos 6 MESES, você teve problemas (como formigamento, dor ou dormência) em alguma parte do corpo: '].astype(int16)  # Ou .astype(int64)
df['Nos últimos 7 DIAS, você teve/tem algum problema/sintoma musculoesquelético?'] = df['Nos últimos 7 DIAS, você teve/tem algum problema/sintoma musculoesquelético?'].astype(int16)  # Ou .astype(int64)
df['IDADE'] = df['IDADE'].astype(int64)

df.to_csv('../Data/ReadyToUse2_Sintomas Musculoesqueléticos em Universitários - Respostas ao formulário 1.csv', sep=",", encoding='latin1', decimal=',', index=False)
